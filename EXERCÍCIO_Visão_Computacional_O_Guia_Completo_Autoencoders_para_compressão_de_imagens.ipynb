# %% [markdown]
# <a href="https://colab.research.google.com/github/FelixEbenezer/Computer-vision/blob/main/EXERC%C3%8DCIO_Vis%C3%A3o_Computacional_O_Guia_Completo_Autoencoders_para_compress%C3%A3o_de_imagens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visão Computacional: O Guia Completo - Autoencoders para compressão de imagens

# %% [markdown]
# ### Importação das bibliotecas

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, AveragePooling2D
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
tf.__version__
# Out:
# '2.6.0'

# %% [markdown]
# ### Carregamento da base de dados
#
# - Dataset: https://keras.io/api/datasets/cifar10/ and https://www.cs.toronto.edu/~kriz/cifar.html

# %%
from tensorflow.keras.datasets import cifar10

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
X_train.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1))

# %%
X_test.shape, y_test.shape
# Out:
# ((10000, 32, 32, 3), (10000, 1))

# %%
32 * 32
# Out:
# 1024

# %% [markdown]
# ### Visualização das imagens

# %%
width = 10
height = 10

fig, axes = plt.subplots(height, width, figsize = (15,15))
axes = axes.ravel()
for i in np.arange(0, width * height):
    index = np.random.randint(0, 50000)
    axes[i].imshow(X_train[index], cmap = 'gray' )
    axes[i].set_title(y_train[index], fontsize = 8)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4);
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# ### Pré-processamento das imagens

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train.shape, X_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %% [markdown]
# ### Construção e treinamento do autoencoder convolucional

# %%
# BatchNormalization: https://keras.io/api/layers/normalization_layers/batch_normalization/

autoencoder = tf.keras.models.Sequential()

# Encoder
autoencoder.add(Conv2D(64, (3,3), activation = 'relu', padding='same', input_shape=(32, 32, 3)))
autoencoder.add(BatchNormalization())
autoencoder.add(AveragePooling2D((2,2), padding="same"))

autoencoder.add(Conv2D(32, (3,3), activation = 'relu', padding='same'))
autoencoder.add(BatchNormalization())
autoencoder.add(AveragePooling2D((2,2), padding="same"))

autoencoder.add(Conv2D(16, (3,3), activation = 'relu', padding="same"))
autoencoder.add(BatchNormalization())
autoencoder.add(AveragePooling2D((2,2), padding="same")) # Imagem codificada

# Decoder
autoencoder.add(Conv2D(16, (3,3), activation = 'relu', padding="same"))
autoencoder.add(BatchNormalization())
autoencoder.add(UpSampling2D((2, 2)))

autoencoder.add(Conv2D(32, (3,3), activation = 'relu', padding="same"))
autoencoder.add(BatchNormalization())
autoencoder.add(UpSampling2D((2, 2)))

autoencoder.add(Conv2D(64, (3,3), activation = 'relu', padding="same"))
autoencoder.add(BatchNormalization())
autoencoder.add(UpSampling2D((2, 2)))

autoencoder.add(Conv2D(3, (3,3), activation='sigmoid', padding="same"))

# %%
autoencoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 32)        18464
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 16)          4624
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 16)          64
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 4, 4, 16)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 16)          2320
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 4, 16)          64
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 32)          4640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 3)         1731
# =================================================================
# Total params: 52,963
# Trainable params: 52,515
# Non-trainable params: 448
# _________________________________________________________________

# %%
# Output = (Input - Filter + 1) / Stride

# %%
autoencoder.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
autoencoder.fit(X_train, X_train, epochs = 50)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 16s 5ms/step - loss: 0.5969 - accuracy: 0.5896
# Epoch 2/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5698 - accuracy: 0.7177
# Epoch 3/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5654 - accuracy: 0.7371
# Epoch 4/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5643 - accuracy: 0.7491
# Epoch 5/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5629 - accuracy: 0.7533
# Epoch 6/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5617 - accuracy: 0.7543
# Epoch 7/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5620 - accuracy: 0.7565
# Epoch 8/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5610 - accuracy: 0.7593
# Epoch 9/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5606 - accuracy: 0.7616
# Epoch 10/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5607 - accuracy: 0.7611
# Epoch 11/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5604 - accuracy: 0.7613
# Epoch 12/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5600 - accuracy: 0.7658
# Epoch 13/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5603 - accuracy: 0.7628
# Epoch 14/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5596 - accuracy: 0.7652
# Epoch 15/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5596 - accuracy: 0.7641
# Epoch 16/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5590 - accuracy: 0.7678
# Epoch 17/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5596 - accuracy: 0.7658
# Epoch 18/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5597 - accuracy: 0.7667
# Epoch 19/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5595 - accuracy: 0.7669
# Epoch 20/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5589 - accuracy: 0.7667
# Epoch 21/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5584 - accuracy: 0.7650
# Epoch 22/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5589 - accuracy: 0.7683
# Epoch 23/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5592 - accuracy: 0.7696
# Epoch 24/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5585 - accuracy: 0.7671
# Epoch 25/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5587 - accuracy: 0.7680
# Epoch 26/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5581 - accuracy: 0.7691
# Epoch 27/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5584 - accuracy: 0.7687
# Epoch 28/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5587 - accuracy: 0.7713
# Epoch 29/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5588 - accuracy: 0.7690
# Epoch 30/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5583 - accuracy: 0.7690
# Epoch 31/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5583 - accuracy: 0.7702
# Epoch 32/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5589 - accuracy: 0.7699
# Epoch 33/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5583 - accuracy: 0.7696
# Epoch 34/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5582 - accuracy: 0.7683
# Epoch 35/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5575 - accuracy: 0.7691
# Epoch 36/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5584 - accuracy: 0.7696
# Epoch 37/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5583 - accuracy: 0.7703
# Epoch 38/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5584 - accuracy: 0.7696
# Epoch 39/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5584 - accuracy: 0.7718
# Epoch 40/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5577 - accuracy: 0.7702
# Epoch 41/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5582 - accuracy: 0.7717
# Epoch 42/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5579 - accuracy: 0.7703
# Epoch 43/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5580 - accuracy: 0.7709
# Epoch 44/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5578 - accuracy: 0.7705
# Epoch 45/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5583 - accuracy: 0.7712
# Epoch 46/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5580 - accuracy: 0.7712
# Epoch 47/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5578 - accuracy: 0.7731
# Epoch 48/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5581 - accuracy: 0.7706
# Epoch 49/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5593 - accuracy: 0.7672
# Epoch 50/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5582 - accuracy: 0.7711

# %% [markdown]
# ### Codificação e decodificação das imagens de teste

# %%
encoder = Model(inputs = autoencoder.input, outputs = autoencoder.get_layer('average_pooling2d_2').output)
encoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_input (InputLayer)    [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 32)        18464
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 16)          4624
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 16)          64
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 4, 4, 16)          0
# =================================================================
# Total params: 25,328
# Trainable params: 25,104
# Non-trainable params: 224
# _________________________________________________________________

# %%
coded_test_images = encoder.predict(X_test)

# %%
coded_test_images.shape
# Out:
# (10000, 4, 4, 16)

# %%
coded_test_images[0]
# Out:
# array([[[-5.23188412e-02, -2.92872995e-01, -6.00532293e-02,
#          -4.18407500e-01,  8.39291513e-02,  2.03679860e-01,
#          -3.09622705e-01, -1.91412300e-01,  3.39883029e-01,
#           4.08226252e-03,  2.41485834e-02,  2.90768743e-01,
#          -4.34977114e-01,  1.21968493e-01,  1.11290276e-01,
#          -2.85019100e-01],
#         [ 2.37003878e-01, -8.32588226e-02,  2.63108015e-02,
#           4.26374197e-01, -1.77812576e-01,  2.00137496e-04,
#           3.00406635e-01],
#         [ 2.40294263e-01,  3.98176074e-01,  3.92813087e-01,
#          -1.54901028e-01,  4.24574018e-02, -1.15554646e-01,
#           2.62286067e-02,  2.04814062e-01,  3.16646695e-02,
#          -8.47935677e-03,  1.26296371e-01,  3.71724889e-02,
#          -1.19465336e-01,  1.39157504e-01,  1.01102605e-01,
#          -1.07880868e-01],
#         [ 1.29928172e-01, -1.15810156e-01,  1.63266957e-01,
#          -9.27529484e-03,  3.36959362e-01,  1.15884602e-01,
#          -1.00169122e-01, -1.56133920e-01, -2.63684869e-01,
#           1.74111351e-01, -4.02813196e-01,  2.04301625e-02,
#          -3.18682969e-01,  2.68091857e-02,  3.32162380e-02,
#          -7.28692412e-02]],
#
#        [[-2.03490108e-01, -3.59676898e-01, -1.38762474e-01,
#           2.26173401e-02,  4.48639393e-01, -2.19373807e-01,
#           1.67875767e-01,  3.59020531e-01, -1.97402894e-01,
#          -4.25009221e-01, -8.88305962e-01, -1.59810647e-01,
#           5.22857010e-01,  5.66181660e-01, -3.57326418e-01,
#          -1.00768745e-01],
#         [ 6.16653562e-02,  5.61184883e-01,  2.94854611e-01,
#           8.75648931e-02, -2.86602139e-01,  2.87835956e-01,
#           3.65860105e-01,  3.15173209e-01, -2.11891964e-01,
#          -1.00857317e-01, -2.02771619e-01,  5.79072893e-01,
#          -2.60999501e-02,  2.21022904e-01, -2.31528789e-01,
#          -1.88102275e-01],
#         [-8.36254433e-02,  5.35595343e-02, -1.46232173e-02,
#          -4.98392433e-02, -9.24379677e-02,  1.23736285e-01,
#           6.56804383e-01,  4.38812912e-01, -1.72187984e-01,
#           5.07998317e-02, -2.96573155e-02, -1.48098633e-01,
#           1.87122524e-01,  3.26666296e-01, -2.94968098e-01,
#          -1.93399131e-01],
#         [-1.55713335e-01,  4.46863174e-01, -2.69670486e-01,
#           1.55499995e-01, -4.96812761e-02, -1.20357692e-01,
#           4.59553599e-01,  3.70529473e-01, -2.59032607e-01,
#           2.02736869e-01, -3.55818927e-01, -7.25433826e-02,
#           1.26041636e-01,  3.40017527e-01, -2.46134013e-01,
#          -1.57731563e-01]]], dtype=float32)

# %%
decoded_test_images = autoencoder.predict(X_test)
decoded_test_images.shape
# Out:
# (10000, 32, 32, 3)

# %%
n_images = 10
test_images = np.random.randint(0, X_test.shape[0], size = n_images)
plt.figure(figsize=(18,18))
for i, image_index in enumerate(test_images):
  
  # Imagem original
  ax = plt.subplot(10,10,i + 1)
  plt.imshow(X_test[image_index].reshape(32,32,3))
  plt.xticks(())
  plt.yticks(())
    
  # Imagem codificada
  ax = plt.subplot(10,10,i + 1 + n_images)
  plt.imshow(coded_test_images[image_index].reshape(16,16))
  plt.xticks(())
  plt.yticks(())
    
  # Imagem decodificada
  ax = plt.subplot(10,10,i + 1 + n_images * 2)
  plt.imshow(decoded_test_images[image_index].reshape(32,32,3))
  plt.xticks(())
  plt.yticks(())
